# %%
# !pip install trimesh
# Out:
# ...
#      ------------------------------------- 688.9/688.9 kB 10.8 MB/s eta 0:00:00
# ...
# WARNING: Ignoring invalid distribution -orch (d:\ia\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\ia\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\ia\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\ia\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\ia\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\ia\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\ia\lib\site-packages)

# %%
import trimesh

# %%
def load_PLY_from_path(path):
    container = []
    for file_path in os.listdir(path):
        las = laspy.read(path + '\\' + file_path)
        container.append(las)
    return container

# %%
train_path = 'D:\\AIDL\\dales_ply\\train'
test_path = 'D:\\AIDL\\dales_ply\\test'

# %%
file_path = "D:\\AIDL\\dales_ply\\train\\5080_54435.ply"
mesh = trimesh.load_mesh(file_path)
mesh.show()

# %%
cpos = ply.plot()
# Out:
# c:\Users\usuari\Desktop\DL\.conda\lib\site-packages\pyvista\jupyter\notebook.py:34: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (c:\Users\usuari\Desktop\DL\.conda\lib\site-packages\trame\widgets\__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
py --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 python --version
#
# NameError: name 'python' is not defined
